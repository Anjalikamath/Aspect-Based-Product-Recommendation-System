# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# %cd /content/drive/My Drive/NLP 2020/Project/classifiers
# Out:
# /content/drive/My Drive/NLP 2020/Project/try

# %%
data=pd.read_csv(r"Dataset_preprocessed.csv")
data.head()
# Out:
#                                                 name  ... negative_words
# 0  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  ...              1
# 1  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  ...              0
# 2  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  ...              0
# 3  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  ...              1
# 4  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  ...              0
#
# [5 rows x 22 columns]

# %%
df=data[['Labels','Feature_0','Product_Name','Feature_1','Feature_2']]

# %%
df.head()
# Out:
#    Labels  ... Feature_2
# 0     1.0  ...       5.0
# 1     1.0  ...       5.0
# 2     1.0  ...       5.0
# 3     1.0  ...       4.0
# 4     1.0  ...       5.0
#
# [5 rows x 5 columns]

# %%
train,test=train_test_split(df,test_size=0.2,random_state=1)

# %%
X_train = train[['Product_Name','Feature_0','Feature_1', 'Feature_2']]
Y_train = train['Labels']

X_test = test[['Product_Name','Feature_0','Feature_1', 'Feature_2']]
Y_test = test['Labels']


df1 = pd.DataFrame(train)
df1.to_csv("train_dataset.csv",index=False)


df2 = pd.DataFrame(test)
df2.to_csv("test_dataset.csv",index=False)

# %% [markdown]
# This notebook is used to split the dataset into training and test sets.
# We have used train_test_split function fro sklearn.We have split the data into 80:20 ratio train:test respectively.
