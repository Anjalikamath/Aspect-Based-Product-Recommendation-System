# %%
import pandas as pd
import numpy as np
import operator
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import accuracy_score

# %%
# %cd /content/drive/My Drive/NLP 2020/Project/Classifiers
# Out:
# /content/drive/My Drive/NLP 2020/Project/try

# %%
#sentiment score and rating is the input

# %%
data = pd.read_csv("train_dataset.csv")
train = data[['Feature_2', 'Feature_1', 'Labels']]

# %%
testdata = pd.read_csv("test_dataset.csv")

df= testdata['Labels']
prod = testdata['Product_Name']

labels_list=df.values.tolist()

# %%
dftestdata = testdata[['Feature_2','Feature_1']]
testdata_list=dftestdata.values.tolist()

# %%
def euclideanDistance(d1, d2, length):
     distance = 0
     for x in range(length):
         distance += np.square(d1[x] - d2[x])
     return np.sqrt(distance)

# %%
def knn(train_data, test_data, k):
    distances = {}
    length = test_data.shape[1]
    for x in range(len(train_data)):
        dist = euclideanDistance(test_data, train_data.iloc[x], length)
        distances[x] = dist[0]
    sorted_d = sorted(distances.items(), key=operator.itemgetter(1))

    neighbors = []

    for x in range(k):
        neighbors.append(sorted_d[x][0])

    classCnt = {}

    for x in range(len(neighbors)):
        response = train_data.iloc[neighbors[x]][-1]

    if response in classCnt:
        classCnt[response] += 1
    else:
        classCnt[response] = 1

    sorted_cnt = sorted(classCnt.items(), key=operator.itemgetter(1), reverse=True)
    return (sorted_cnt[0][0], neighbors)

# %%
k = 10
predicted_data=[]

for x in testdata_list:
    testSet=x
    predict = pd.DataFrame(testSet)
    result, neigh = knn(train, predict, k)
    predicted_data.append(result)

# %%
results = confusion_matrix(labels_list, predicted_data,labels=[1,-1])
print('Confusion Matrix:')
print(results)

print(classification_report(labels_list, predicted_data))

print('Accuracy Score :', accuracy_score(labels_list, predicted_data))

# %%
products = []
for x in prod:
        products.append(x)

# %%
complete_list = []
def perf_measure(products,y_actual, y_pred):

    for i in range(len(y_pred)):
        TP = 0
        FP = 0
        TN = 0
        FN = 0
        if y_actual[i]==y_pred[i]==1:
           TP += 1
        if y_pred[i]==1 and y_actual[i]!=y_pred[i]:
           FP += 1
        if y_actual[i]==y_pred[i]==-1:
           TN += 1
        if y_pred[i]==-1 and y_actual[i]!=y_pred[i]:
           FN += 1

        complete_list.append([products[i],y_actual[i],y_pred[i],TP, FP, TN, FN])

# %%
perf_measure(products, labels_list, predicted_data)
header = ['Products_Name','Actual','Predicted','TP','FP','TN','FN']
dfObj = pd.DataFrame(complete_list,columns=header)
dfObj.to_csv("Output_KNN.csv",index=False)

# %%
dfObj.head(20)
# Out:
#                                         Products_Name  Actual  ...  TN  FN
# 0   Amazon Kindle Paperwhite  eBook reader   GB   ...    -1.0  ...   1   0
# 1   Fire Tablet  Display WiFi  GB  Includes Specia...    -1.0  ...   1   0
# 2   Fire Tablet  Display WiFi  GB  Includes Specia...    -1.0  ...   1   0
# 3   Fire Tablet  Display WiFi  GB  Includes Specia...     1.0  ...   0   0
# 4   Fire Kids Edition Tablet  Display WiFi  GB Gre...    -1.0  ...   1   0
# 5   Brand New Amazon Kindle Fire gb  Ips Display T...    -1.0  ...   1   0
# 6   Fire Tablet  Display WiFi  GB  Includes Specia...     1.0  ...   0   0
# 7   AllNew Fire HD  Tablet  HD Display WiFi  GB  I...     1.0  ...   0   0
# 8   Fire Tablet  Display WiFi  GB  Includes Specia...    -1.0  ...   1   0
# 9   Fire Kids Edition Tablet  Display WiFi  GB Gre...     1.0  ...   0   0
# 10  Fire Tablet  Display WiFi  GB  Includes Specia...     1.0  ...   0   1
# ...

# %% [markdown]
# In this notebook,the knn algorithm is implemented.The confusion matrix along with the accuracy,precision,recall and f1 score is printed as the performance measure for the given data. The ouput of each predicted product is saved into a separate csv file "Output_KNN.csv"
#
# On getting the training data,it is plotted in the n-dimensional space.Then given the test data,for each point in the test data ,the eucledian distance of the point to the points in the training data is calculated.This distance is then sorted in the ascending order the first k values are extracted.Then the labels corresponding to these k values is taken and the label occuring maximum number of times in these k values is selected as the label for the test point.
#
# Input:
# train_dataset.csv and test_dataset.csv
#
# Output:
# Output_KNN.csv , Confusion matrix and accuracy.
